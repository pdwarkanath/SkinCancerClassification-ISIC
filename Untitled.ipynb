# %%
import PIL
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_loc = '../ISIC2018_Task3_Training_Input/'
img_name = 'ISIC_0025453.jpg'

# %%
img = plt.imread(img_loc+img_name,)

# %%
img_new = np.empty(img.shape)
img_new[:,:,:] = img[:,:,:]
img_new[:,:,0] = abs(img[:,:,0] - 30)
plt.imshow(img)

# %%
np.argmin(img[:,:,1])
# Out:
# 267598
